# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
import time

# Import the API key.
from config import weather_api_key
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
#latitudes
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
#longitues
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
#keep the latitudes and longitudes as pairs
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities names
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 762

# %% [markdown]
# ### Import Dependencies, and Initialize an Empty List and Counters

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID="+ weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list, iterating through the list of cities
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
   
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_desc = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
       
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_desc
                          })

# If an error is experienced, skip the city. 
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nacajuca
# Processing Record 2 of Set 1 | bluff
# Processing Record 3 of Set 1 | castro
# Processing Record 4 of Set 1 | tasiilaq
# Processing Record 5 of Set 1 | aquiraz
# Processing Record 6 of Set 1 | souillac
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | namie
# Processing Record 9 of Set 1 | kapaa
# Processing Record 10 of Set 1 | oranjemund
# Processing Record 11 of Set 1 | marystown
# Processing Record 12 of Set 1 | disna
# Processing Record 13 of Set 1 | ahipara
# Processing Record 14 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 15 of Set 1 | chokurdakh
# Processing Record 16 of Set 1 | upernavik
# Processing Record 17 of Set 1 | deputatskiy
# Processing Record 18 of Set 1 | cidreira
# Processing Record 19 of Set 1 | khonuu
# City not found. Skipping...
# Processing Record 20 of Set 1 | caravelas
# Processing Record 21 of Set 1 | pevek
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | cape town
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | pangnirtung
# Processing Record 27 of Set 1 | kirakira
# Processing Record 28 of Set 1 | port elizabeth
# Processing Record 29 of Set 1 | thompson
# Processing Record 30 of Set 1 | port alfred
# Processing Record 31 of Set 1 | ushuaia
# Processing Record 32 of Set 1 | victoria
# Processing Record 33 of Set 1 | taoudenni
# Processing Record 34 of Set 1 | foundiougne
# Processing Record 35 of Set 1 | simao
# Processing Record 36 of Set 1 | necochea
# Processing Record 37 of Set 1 | buon me thuot
# City not found. Skipping...
# Processing Record 38 of Set 1 | qaanaaq
# Processing Record 39 of Set 1 | nanortalik
# Processing Record 40 of Set 1 | zhigansk
# Processing Record 41 of Set 1 | kaseda
# Processing Record 42 of Set 1 | vestmannaeyjar
# Processing Record 43 of Set 1 | college
# Processing Record 44 of Set 1 | akyab
# Processing Record 45 of Set 1 | tabialan
# City not found. Skipping...
# Processing Record 46 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 1 | ambilobe
# Processing Record 48 of Set 1 | laguna
# Processing Record 49 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 50 of Set 1 | monrovia
# Processing Record 1 of Set 2 | baldone
# Processing Record 2 of Set 2 | chumphon
# Processing Record 3 of Set 2 | lazaro cardenas
# Processing Record 4 of Set 2 | punta arenas
# Processing Record 5 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 6 of Set 2 | sioux lookout
# Processing Record 7 of Set 2 | tateyama
# Processing Record 8 of Set 2 | portland
# Processing Record 9 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 10 of Set 2 | yellowknife
# Processing Record 11 of Set 2 | west bay
# Processing Record 12 of Set 2 | goleniow
# Processing Record 13 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 14 of Set 2 | lancaster
# Processing Record 15 of Set 2 | arman
# Processing Record 16 of Set 2 | uhlove
# Processing Record 17 of Set 2 | albany
# Processing Record 18 of Set 2 | chulumani
# Processing Record 19 of Set 2 | carnarvon
# Processing Record 20 of Set 2 | katsuura
# Processing Record 21 of Set 2 | hithadhoo
# Processing Record 22 of Set 2 | lulea
# Processing Record 23 of Set 2 | nalut
# Processing Record 24 of Set 2 | kununurra
# Processing Record 25 of Set 2 | baffa
# Processing Record 26 of Set 2 | kaniv
# Processing Record 27 of Set 2 | san andres
# Processing Record 28 of Set 2 | new norfolk
# Processing Record 29 of Set 2 | vaini
# Processing Record 30 of Set 2 | shihezi
# Processing Record 31 of Set 2 | puerto ayora
# Processing Record 32 of Set 2 | jiangyou
# Processing Record 33 of Set 2 | esperance
# Processing Record 34 of Set 2 | sao cristovao
# Processing Record 35 of Set 2 | myitkyina
# Processing Record 36 of Set 2 | puerto narino
# Processing Record 37 of Set 2 | orcopampa
# Processing Record 38 of Set 2 | saint-philippe
# Processing Record 39 of Set 2 | jakoruda
# City not found. Skipping...
# Processing Record 40 of Set 2 | namibe
# Processing Record 41 of Set 2 | selje
# Processing Record 42 of Set 2 | balclutha
# Processing Record 43 of Set 2 | longyearbyen
# Processing Record 44 of Set 2 | nakhon phanom
# Processing Record 45 of Set 2 | santa vitoria do palmar
# Processing Record 46 of Set 2 | matao
# Processing Record 47 of Set 2 | cherskiy
# Processing Record 48 of Set 2 | hobart
# Processing Record 49 of Set 2 | attawapiskat
# City not found. Skipping...
# Processing Record 50 of Set 2 | chuy
# Processing Record 1 of Set 3 | mandalgovi
# Processing Record 2 of Set 3 | yarmouth
# Processing Record 3 of Set 3 | kaitangata
# Processing Record 4 of Set 3 | buala
# Processing Record 5 of Set 3 | shebunino
# Processing Record 6 of Set 3 | itoman
# Processing Record 7 of Set 3 | barrow
# Processing Record 8 of Set 3 | arraial do cabo
# Processing Record 9 of Set 3 | jamestown
# Processing Record 10 of Set 3 | mbengwi
# Processing Record 11 of Set 3 | cabinda
# Processing Record 12 of Set 3 | bredasdorp
# Processing Record 13 of Set 3 | east london
# Processing Record 14 of Set 3 | kalevala
# Processing Record 15 of Set 3 | correntina
# Processing Record 16 of Set 3 | hermanus
# Processing Record 17 of Set 3 | narsaq
# Processing Record 18 of Set 3 | dunmore town
# Processing Record 19 of Set 3 | dikson
# Processing Record 20 of Set 3 | abbeville
# Processing Record 21 of Set 3 | fomboni
# Processing Record 22 of Set 3 | solnechnyy
# Processing Record 23 of Set 3 | kitimat
# Processing Record 24 of Set 3 | alofi
# Processing Record 25 of Set 3 | cabo san lucas
# Processing Record 26 of Set 3 | quatre cocos
# Processing Record 27 of Set 3 | avarua
# Processing Record 28 of Set 3 | provideniya
# Processing Record 29 of Set 3 | tuktoyaktuk
# Processing Record 30 of Set 3 | heihe
# Processing Record 31 of Set 3 | saint-augustin
# Processing Record 32 of Set 3 | sistranda
# Processing Record 33 of Set 3 | sokoni
# Processing Record 34 of Set 3 | inirida
# Processing Record 35 of Set 3 | clyde river
# Processing Record 36 of Set 3 | sorong
# Processing Record 37 of Set 3 | maragogi
# Processing Record 38 of Set 3 | nuevo laredo
# Processing Record 39 of Set 3 | provost
# Processing Record 40 of Set 3 | amga
# Processing Record 41 of Set 3 | srednekolymsk
# Processing Record 42 of Set 3 | pacific grove
# Processing Record 43 of Set 3 | nikolskoye
# Processing Record 44 of Set 3 | jackson
# Processing Record 45 of Set 3 | guerrero negro
# Processing Record 46 of Set 3 | jega
# Processing Record 47 of Set 3 | jumla
# Processing Record 48 of Set 3 | san bernardo
# Processing Record 49 of Set 3 | ixtapa
# Processing Record 50 of Set 3 | tyler
# Processing Record 1 of Set 4 | nome
# Processing Record 2 of Set 4 | coihaique
# Processing Record 3 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 4 | tazovskiy
# Processing Record 5 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 4 | hami
# Processing Record 7 of Set 4 | gizo
# Processing Record 8 of Set 4 | el alto
# Processing Record 9 of Set 4 | khasan
# Processing Record 10 of Set 4 | kavieng
# Processing Record 11 of Set 4 | iquique
# Processing Record 12 of Set 4 | iquitos
# Processing Record 13 of Set 4 | mergui
# City not found. Skipping...
# Processing Record 14 of Set 4 | ancud
# Processing Record 15 of Set 4 | lebu
# Processing Record 16 of Set 4 | dubuque
# Processing Record 17 of Set 4 | saint george
# Processing Record 18 of Set 4 | zanzibar
# Processing Record 19 of Set 4 | nedjo
# Processing Record 20 of Set 4 | atbasar
# Processing Record 21 of Set 4 | pisco
# Processing Record 22 of Set 4 | hilo
# Processing Record 23 of Set 4 | aykhal
# Processing Record 24 of Set 4 | natal
# Processing Record 25 of Set 4 | te anau
# Processing Record 26 of Set 4 | khatanga
# Processing Record 27 of Set 4 | empa
# City not found. Skipping...
# Processing Record 28 of Set 4 | lar
# Processing Record 29 of Set 4 | lourdes
# Processing Record 30 of Set 4 | paamiut
# Processing Record 31 of Set 4 | luderitz
# Processing Record 32 of Set 4 | aasiaat
# Processing Record 33 of Set 4 | alyangula
# Processing Record 34 of Set 4 | westport
# Processing Record 35 of Set 4 | vostok
# Processing Record 36 of Set 4 | alghero
# Processing Record 37 of Set 4 | lyuban
# Processing Record 38 of Set 4 | klaksvik
# Processing Record 39 of Set 4 | polyarnyy
# Processing Record 40 of Set 4 | broome
# Processing Record 41 of Set 4 | sinnamary
# Processing Record 42 of Set 4 | koulikoro
# Processing Record 43 of Set 4 | kormilovka
# Processing Record 44 of Set 4 | asau
# Processing Record 45 of Set 4 | yulara
# Processing Record 46 of Set 4 | osoyoos
# Processing Record 47 of Set 4 | fort nelson
# Processing Record 48 of Set 4 | ouesso
# Processing Record 49 of Set 4 | camrose
# Processing Record 50 of Set 4 | phan thiet
# Processing Record 1 of Set 5 | lompoc
# Processing Record 2 of Set 5 | zonguldak
# Processing Record 3 of Set 5 | cayenne
# Processing Record 4 of Set 5 | tuatapere
# Processing Record 5 of Set 5 | port lincoln
# Processing Record 6 of Set 5 | weyburn
# Processing Record 7 of Set 5 | constitucion
# Processing Record 8 of Set 5 | mahebourg
# Processing Record 9 of Set 5 | asfi
# Processing Record 10 of Set 5 | yining
# Processing Record 11 of Set 5 | meru
# Processing Record 12 of Set 5 | kupang
# Processing Record 13 of Set 5 | betioky
# Processing Record 14 of Set 5 | meulaboh
# Processing Record 15 of Set 5 | vila franca do campo
# Processing Record 16 of Set 5 | atambua
# Processing Record 17 of Set 5 | kiama
# Processing Record 18 of Set 5 | norman wells
# Processing Record 19 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 20 of Set 5 | mount isa
# Processing Record 21 of Set 5 | ponta do sol
# Processing Record 22 of Set 5 | port-gentil
# Processing Record 23 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 24 of Set 5 | hualmay
# Processing Record 25 of Set 5 | youghal
# Processing Record 26 of Set 5 | labuan
# Processing Record 27 of Set 5 | talcahuano
# Processing Record 28 of Set 5 | vardo
# Processing Record 29 of Set 5 | surt
# Processing Record 30 of Set 5 | mar del plata
# Processing Record 31 of Set 5 | samarai
# Processing Record 32 of Set 5 | champoton
# Processing Record 33 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 5 | merauke
# Processing Record 35 of Set 5 | salalah
# Processing Record 36 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 37 of Set 5 | rovaniemi
# Processing Record 38 of Set 5 | bairiki
# Processing Record 39 of Set 5 | omboue
# Processing Record 40 of Set 5 | fairbanks
# Processing Record 41 of Set 5 | yerbogachen
# Processing Record 42 of Set 5 | kodiak
# Processing Record 43 of Set 5 | lubumbashi
# Processing Record 44 of Set 5 | baculin
# Processing Record 45 of Set 5 | puerto baquerizo moreno
# Processing Record 46 of Set 5 | hasaki
# Processing Record 47 of Set 5 | vila
# Processing Record 48 of Set 5 | mehamn
# Processing Record 49 of Set 5 | sijunjung
# Processing Record 50 of Set 5 | naze
# Processing Record 1 of Set 6 | aswan
# Processing Record 2 of Set 6 | king city
# Processing Record 3 of Set 6 | leningradskiy
# Processing Record 4 of Set 6 | airai
# Processing Record 5 of Set 6 | puchov
# Processing Record 6 of Set 6 | banda aceh
# Processing Record 7 of Set 6 | chicama
# Processing Record 8 of Set 6 | labuhan
# Processing Record 9 of Set 6 | fortuna
# Processing Record 10 of Set 6 | alice springs
# Processing Record 11 of Set 6 | nuuk
# Processing Record 12 of Set 6 | torbay
# Processing Record 13 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 6 | rosarito
# Processing Record 15 of Set 6 | ampanihy
# Processing Record 16 of Set 6 | mozarlandia
# Processing Record 17 of Set 6 | lorengau
# Processing Record 18 of Set 6 | marsa matruh
# Processing Record 19 of Set 6 | karratha
# Processing Record 20 of Set 6 | mangan
# Processing Record 21 of Set 6 | ribeira grande
# Processing Record 22 of Set 6 | vila velha
# Processing Record 23 of Set 6 | velyka bilozerka
# Processing Record 24 of Set 6 | punta cardon
# Processing Record 25 of Set 6 | tsiroanomandidy
# Processing Record 26 of Set 6 | kaya
# Processing Record 27 of Set 6 | nouadhibou
# Processing Record 28 of Set 6 | fergus falls
# Processing Record 29 of Set 6 | butaritari
# Processing Record 30 of Set 6 | bengkulu
# Processing Record 31 of Set 6 | plouzane
# Processing Record 32 of Set 6 | jacqueville
# Processing Record 33 of Set 6 | mangrol
# Processing Record 34 of Set 6 | biak
# Processing Record 35 of Set 6 | tautira
# Processing Record 36 of Set 6 | karamea
# City not found. Skipping...
# Processing Record 37 of Set 6 | vung tau
# Processing Record 38 of Set 6 | drayton valley
# Processing Record 39 of Set 6 | killybegs
# Processing Record 40 of Set 6 | huayang
# Processing Record 41 of Set 6 | manama
# Processing Record 42 of Set 6 | virginia beach
# Processing Record 43 of Set 6 | banepa
# Processing Record 44 of Set 6 | nainpur
# Processing Record 45 of Set 6 | isangel
# Processing Record 46 of Set 6 | kedrovyy
# Processing Record 47 of Set 6 | sitka
# Processing Record 48 of Set 6 | aguimes
# Processing Record 49 of Set 6 | christchurch
# Processing Record 50 of Set 6 | porto novo
# Processing Record 1 of Set 7 | tiksi
# Processing Record 2 of Set 7 | palana
# Processing Record 3 of Set 7 | bokoro
# Processing Record 4 of Set 7 | cascais
# Processing Record 5 of Set 7 | nuevitas
# Processing Record 6 of Set 7 | liwale
# Processing Record 7 of Set 7 | juegang
# Processing Record 8 of Set 7 | walvis bay
# Processing Record 9 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 10 of Set 7 | linguere
# Processing Record 11 of Set 7 | georgetown
# Processing Record 12 of Set 7 | utiroa
# City not found. Skipping...
# Processing Record 13 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 14 of Set 7 | prince george
# Processing Record 15 of Set 7 | tingrela
# City not found. Skipping...
# Processing Record 16 of Set 7 | kenai
# Processing Record 17 of Set 7 | pandan
# Processing Record 18 of Set 7 | bethel
# Processing Record 19 of Set 7 | kavaratti
# Processing Record 20 of Set 7 | pudozh
# Processing Record 21 of Set 7 | emba
# Processing Record 22 of Set 7 | hambantota
# Processing Record 23 of Set 7 | cockburn town
# Processing Record 24 of Set 7 | lata
# Processing Record 25 of Set 7 | manali
# Processing Record 26 of Set 7 | dingle
# Processing Record 27 of Set 7 | coquimbo
# Processing Record 28 of Set 7 | seoul
# Processing Record 29 of Set 7 | semey
# Processing Record 30 of Set 7 | kahului
# Processing Record 31 of Set 7 | chutung
# City not found. Skipping...
# Processing Record 32 of Set 7 | nishihara
# Processing Record 33 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 7 | palabuhanratu
# City not found. Skipping...
# Processing Record 35 of Set 7 | maydolong
# Processing Record 36 of Set 7 | touros
# Processing Record 37 of Set 7 | carbonia
# Processing Record 38 of Set 7 | makakilo city
# Processing Record 39 of Set 7 | uskedal
# City not found. Skipping...
# Processing Record 40 of Set 7 | matara
# Processing Record 41 of Set 7 | leshukonskoye
# Processing Record 42 of Set 7 | kutum
# Processing Record 43 of Set 7 | california city
# Processing Record 44 of Set 7 | bathsheba
# Processing Record 45 of Set 7 | stolin
# Processing Record 46 of Set 7 | dire dawa
# Processing Record 47 of Set 7 | jinji
# Processing Record 48 of Set 7 | ust-tsilma
# Processing Record 49 of Set 7 | kudahuvadhoo
# Processing Record 50 of Set 7 | lavrentiya
# Processing Record 1 of Set 8 | salamiyah
# Processing Record 2 of Set 8 | belmonte
# Processing Record 3 of Set 8 | marawi
# Processing Record 4 of Set 8 | lodwar
# Processing Record 5 of Set 8 | kautokeino
# Processing Record 6 of Set 8 | udachnyy
# Processing Record 7 of Set 8 | abaetetuba
# Processing Record 8 of Set 8 | sobolevo
# Processing Record 9 of Set 8 | nachingwea
# Processing Record 10 of Set 8 | dunedin
# Processing Record 11 of Set 8 | ouargaye
# Processing Record 12 of Set 8 | vao
# Processing Record 13 of Set 8 | goure
# Processing Record 14 of Set 8 | hobyo
# Processing Record 15 of Set 8 | zheleznodorozhnyy
# Processing Record 16 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 17 of Set 8 | bath
# Processing Record 18 of Set 8 | yauya
# Processing Record 19 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 20 of Set 8 | saldanha
# Processing Record 21 of Set 8 | lagos
# Processing Record 22 of Set 8 | sheridan
# Processing Record 23 of Set 8 | nizhniy baskunchak
# Processing Record 24 of Set 8 | hailar
# Processing Record 25 of Set 8 | itaituba
# Processing Record 26 of Set 8 | privokzalnyy
# City not found. Skipping...
# Processing Record 27 of Set 8 | naryan-mar
# Processing Record 28 of Set 8 | janauba
# Processing Record 29 of Set 8 | kovur
# Processing Record 30 of Set 8 | puerto plata
# Processing Record 31 of Set 8 | viedma
# Processing Record 32 of Set 8 | severo-kurilsk
# Processing Record 33 of Set 8 | ilo
# Processing Record 34 of Set 8 | luanda
# Processing Record 35 of Set 8 | saskylakh
# Processing Record 36 of Set 8 | poum
# Processing Record 37 of Set 8 | yuza
# Processing Record 38 of Set 8 | saint-leu
# Processing Record 39 of Set 8 | egvekinot
# Processing Record 40 of Set 8 | boguchany
# Processing Record 41 of Set 8 | cheyur
# City not found. Skipping...
# Processing Record 42 of Set 8 | lokosovo
# Processing Record 43 of Set 8 | aksu
# Processing Record 44 of Set 8 | dubbo
# Processing Record 45 of Set 8 | teya
# Processing Record 46 of Set 8 | stornoway
# Processing Record 47 of Set 8 | koraput
# Processing Record 48 of Set 8 | ilulissat
# Processing Record 49 of Set 8 | aklavik
# Processing Record 50 of Set 8 | sur
# Processing Record 1 of Set 9 | maniitsoq
# Processing Record 2 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 3 of Set 9 | miandrivazo
# Processing Record 4 of Set 9 | oranzherei
# Processing Record 5 of Set 9 | baturaja
# Processing Record 6 of Set 9 | solsvik
# City not found. Skipping...
# Processing Record 7 of Set 9 | lake havasu city
# Processing Record 8 of Set 9 | oros
# Processing Record 9 of Set 9 | chitral
# Processing Record 10 of Set 9 | ntungamo
# Processing Record 11 of Set 9 | harper
# Processing Record 12 of Set 9 | la ronge
# Processing Record 13 of Set 9 | stephenville
# Processing Record 14 of Set 9 | waihi beach
# Processing Record 15 of Set 9 | hovd
# Processing Record 16 of Set 9 | xacmaz
# Processing Record 17 of Set 9 | impfondo
# Processing Record 18 of Set 9 | novobessergenevka
# Processing Record 19 of Set 9 | codrington
# Processing Record 20 of Set 9 | boueni
# Processing Record 21 of Set 9 | nuevo progreso
# Processing Record 22 of Set 9 | kouango
# Processing Record 23 of Set 9 | umtata
# Processing Record 24 of Set 9 | andros town
# Processing Record 25 of Set 9 | tigil
# Processing Record 26 of Set 9 | gopalpur
# Processing Record 27 of Set 9 | marzuq
# Processing Record 28 of Set 9 | smithville
# Processing Record 29 of Set 9 | wenshang
# Processing Record 30 of Set 9 | kawalu
# Processing Record 31 of Set 9 | hihifo
# City not found. Skipping...
# Processing Record 32 of Set 9 | faanui
# Processing Record 33 of Set 9 | sakakah
# Processing Record 34 of Set 9 | tual
# Processing Record 35 of Set 9 | tarnos
# Processing Record 36 of Set 9 | saint-joseph
# Processing Record 37 of Set 9 | tura
# Processing Record 38 of Set 9 | najran
# Processing Record 39 of Set 9 | lagoa
# Processing Record 40 of Set 9 | muhos
# Processing Record 41 of Set 9 | tapaua
# City not found. Skipping...
# Processing Record 42 of Set 9 | solovetskiy
# City not found. Skipping...
# Processing Record 43 of Set 9 | awbari
# Processing Record 44 of Set 9 | ornskoldsvik
# Processing Record 45 of Set 9 | pauini
# Processing Record 46 of Set 9 | auki
# Processing Record 47 of Set 9 | zalari
# Processing Record 48 of Set 9 | batagay-alyta
# Processing Record 49 of Set 9 | la palma
# Processing Record 50 of Set 9 | spanish fork
# Processing Record 1 of Set 10 | tawnat
# City not found. Skipping...
# Processing Record 2 of Set 10 | ambanja
# Processing Record 3 of Set 10 | novo aripuana
# Processing Record 4 of Set 10 | long beach
# Processing Record 5 of Set 10 | mizan teferi
# Processing Record 6 of Set 10 | pervomayskaya
# Processing Record 7 of Set 10 | mount gambier
# Processing Record 8 of Set 10 | caucaia
# Processing Record 9 of Set 10 | ciro marina
# Processing Record 10 of Set 10 | vanimo
# Processing Record 11 of Set 10 | thinadhoo
# Processing Record 12 of Set 10 | bismarck
# Processing Record 13 of Set 10 | magdagachi
# Processing Record 14 of Set 10 | prince rupert
# Processing Record 15 of Set 10 | avera
# Processing Record 16 of Set 10 | kotido
# Processing Record 17 of Set 10 | port blair
# Processing Record 18 of Set 10 | huilong
# Processing Record 19 of Set 10 | nisia floresta
# Processing Record 20 of Set 10 | along
# Processing Record 21 of Set 10 | pravda
# Processing Record 22 of Set 10 | bandarbeyla
# Processing Record 23 of Set 10 | muros
# Processing Record 24 of Set 10 | azare
# Processing Record 25 of Set 10 | abu samrah
# Processing Record 26 of Set 10 | sept-iles
# Processing Record 27 of Set 10 | conakry
# Processing Record 28 of Set 10 | iqaluit
# Processing Record 29 of Set 10 | nurota
# Processing Record 30 of Set 10 | severomuysk
# Processing Record 31 of Set 10 | touho
# Processing Record 32 of Set 10 | geraldton
# Processing Record 33 of Set 10 | san quintin
# Processing Record 34 of Set 10 | wattegama
# Processing Record 35 of Set 10 | port hardy
# Processing Record 36 of Set 10 | celina
# Processing Record 37 of Set 10 | tessalit
# Processing Record 38 of Set 10 | jalu
# Processing Record 39 of Set 10 | toliary
# City not found. Skipping...
# Processing Record 40 of Set 10 | ranao
# Processing Record 41 of Set 10 | grand gaube
# Processing Record 42 of Set 10 | ambodifototra
# City not found. Skipping...
# Processing Record 43 of Set 10 | maridi
# Processing Record 44 of Set 10 | salta
# Processing Record 45 of Set 10 | beitbridge
# Processing Record 46 of Set 10 | the valley
# Processing Record 47 of Set 10 | point fortin
# Processing Record 48 of Set 10 | sao joao da barra
# Processing Record 49 of Set 10 | lagunas
# Processing Record 50 of Set 10 | dharur
# Processing Record 1 of Set 11 | cairns
# Processing Record 2 of Set 11 | san giovanni in fiore
# Processing Record 3 of Set 11 | okha
# Processing Record 4 of Set 11 | praia
# Processing Record 5 of Set 11 | olafsvik
# Processing Record 6 of Set 11 | sungaipenuh
# Processing Record 7 of Set 11 | lakota
# Processing Record 8 of Set 11 | saint-pierre
# Processing Record 9 of Set 11 | cabedelo
# Processing Record 10 of Set 11 | riyadh
# Processing Record 11 of Set 11 | luganville
# Processing Record 12 of Set 11 | okhotsk
# Processing Record 13 of Set 11 | inhambane
# Processing Record 14 of Set 11 | tarbes
# Processing Record 15 of Set 11 | hofn
# Processing Record 16 of Set 11 | kpandae
# Processing Record 17 of Set 11 | bakchar
# Processing Record 18 of Set 11 | bulgan
# Processing Record 19 of Set 11 | burica
# City not found. Skipping...
# Processing Record 20 of Set 11 | tambura
# Processing Record 21 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 22 of Set 11 | manggar
# Processing Record 23 of Set 11 | general pico
# Processing Record 24 of Set 11 | taonan
# Processing Record 25 of Set 11 | kuhestan
# City not found. Skipping...
# Processing Record 26 of Set 11 | visby
# Processing Record 27 of Set 11 | henties bay
# Processing Record 28 of Set 11 | tuggurt
# City not found. Skipping...
# Processing Record 29 of Set 11 | kanakapura
# Processing Record 30 of Set 11 | mayo
# Processing Record 31 of Set 11 | canitas
# City not found. Skipping...
# Processing Record 32 of Set 11 | batkovici
# City not found. Skipping...
# Processing Record 33 of Set 11 | hohhot
# Processing Record 34 of Set 11 | baghdad
# Processing Record 35 of Set 11 | rapid valley
# Processing Record 36 of Set 11 | finote selam
# Processing Record 37 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 38 of Set 11 | los llanos de aridane
# Processing Record 39 of Set 11 | neiafu
# Processing Record 40 of Set 11 | lufilufi
# Processing Record 41 of Set 11 | mumbwa
# Processing Record 42 of Set 11 | nortelandia
# Processing Record 43 of Set 11 | colares
# Processing Record 44 of Set 11 | ruatoria
# City not found. Skipping...
# Processing Record 45 of Set 11 | vallenar
# Processing Record 46 of Set 11 | brae
# Processing Record 47 of Set 11 | riohacha
# Processing Record 48 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 49 of Set 11 | mogok
# Processing Record 50 of Set 11 | kaeo
# Processing Record 1 of Set 12 | ust-kuyga
# Processing Record 2 of Set 12 | livingston
# Processing Record 3 of Set 12 | vyara
# Processing Record 4 of Set 12 | trairi
# Processing Record 5 of Set 12 | astana
# Processing Record 6 of Set 12 | richards bay
# Processing Record 7 of Set 12 | mexico
# Processing Record 8 of Set 12 | lasa
# Processing Record 9 of Set 12 | dwarka
# Processing Record 10 of Set 12 | nizhneyansk
# City not found. Skipping...
# Processing Record 11 of Set 12 | bambous virieux
# Processing Record 12 of Set 12 | plettenberg bay
# Processing Record 13 of Set 12 | ushtobe
# Processing Record 14 of Set 12 | bend
# Processing Record 15 of Set 12 | cheuskiny
# City not found. Skipping...
# Processing Record 16 of Set 12 | tilichiki
# Processing Record 17 of Set 12 | santiago del estero
# Processing Record 18 of Set 12 | zilupe
# Processing Record 19 of Set 12 | nara
# Processing Record 20 of Set 12 | obidos
# Processing Record 21 of Set 12 | ijaki
# City not found. Skipping...
# Processing Record 22 of Set 12 | tiarei
# Processing Record 23 of Set 12 | santa rosa
# Processing Record 24 of Set 12 | suntar
# Processing Record 25 of Set 12 | ostrovnoy
# Processing Record 26 of Set 12 | jibuti
# Processing Record 27 of Set 12 | mercedes
# Processing Record 28 of Set 12 | aitape
# Processing Record 29 of Set 12 | bayburt
# Processing Record 30 of Set 12 | rundu
# Processing Record 31 of Set 12 | coruche
# Processing Record 32 of Set 12 | dutlwe
# Processing Record 33 of Set 12 | la asuncion
# Processing Record 34 of Set 12 | krasnoselkup
# Processing Record 35 of Set 12 | chuchkovo
# Processing Record 36 of Set 12 | yanchukan
# City not found. Skipping...
# Processing Record 37 of Set 12 | grindavik
# Processing Record 38 of Set 12 | cedral
# Processing Record 39 of Set 12 | ankazoabo
# Processing Record 40 of Set 12 | tetouan
# Processing Record 41 of Set 12 | cap malheureux
# Processing Record 42 of Set 12 | candido mendes
# Processing Record 43 of Set 12 | klyuchevskiy
# Processing Record 44 of Set 12 | kachikau
# City not found. Skipping...
# Processing Record 45 of Set 12 | nikki
# Processing Record 46 of Set 12 | moree
# Processing Record 47 of Set 12 | rassvet
# Processing Record 48 of Set 12 | hamilton
# Processing Record 49 of Set 12 | springdale
# Processing Record 50 of Set 12 | alta floresta
# Processing Record 1 of Set 13 | praia da vitoria
# Processing Record 2 of Set 13 | toora-khem
# Processing Record 3 of Set 13 | naftah
# City not found. Skipping...
# Processing Record 4 of Set 13 | coahuayana
# Processing Record 5 of Set 13 | sao pedro do sul
# Processing Record 6 of Set 13 | galesong
# Processing Record 7 of Set 13 | muisne
# Processing Record 8 of Set 13 | chittaurgarh
# Processing Record 9 of Set 13 | dafeng
# Processing Record 10 of Set 13 | amatlan
# City not found. Skipping...
# Processing Record 11 of Set 13 | adrar
# Processing Record 12 of Set 13 | khromtau
# Processing Record 13 of Set 13 | puerto escondido
# Processing Record 14 of Set 13 | libreville
# Processing Record 15 of Set 13 | santa margherita ligure
# Processing Record 16 of Set 13 | uarini
# Processing Record 17 of Set 13 | mana
# Processing Record 18 of Set 13 | soledar
# Processing Record 19 of Set 13 | san patricio
# Processing Record 20 of Set 13 | verkhovazhye
# Processing Record 21 of Set 13 | portel
# Processing Record 22 of Set 13 | krasnogorskiy
# Processing Record 23 of Set 13 | kruisfontein
# Processing Record 24 of Set 13 | garissa
# Processing Record 25 of Set 13 | atlantic city
# Processing Record 26 of Set 13 | weligama
# Processing Record 27 of Set 13 | port macquarie
# Processing Record 28 of Set 13 | malakal
# Processing Record 29 of Set 13 | muli
# Processing Record 30 of Set 13 | xitla
# City not found. Skipping...
# Processing Record 31 of Set 13 | canton
# Processing Record 32 of Set 13 | pangoa
# Processing Record 33 of Set 13 | tiznit
# Processing Record 34 of Set 13 | nabire
# Processing Record 35 of Set 13 | kiunga
# Processing Record 36 of Set 13 | bayeux
# Processing Record 37 of Set 13 | marau
# Processing Record 38 of Set 13 | timiryazevskiy
# Processing Record 39 of Set 13 | grand baie
# Processing Record 40 of Set 13 | wanning
# Processing Record 41 of Set 13 | carahue
# Processing Record 42 of Set 13 | curuguaty
# Processing Record 43 of Set 13 | tubuala
# Processing Record 44 of Set 13 | abilene
# Processing Record 45 of Set 13 | ayan
# Processing Record 46 of Set 13 | algiers
# Processing Record 47 of Set 13 | halifax
# Processing Record 48 of Set 13 | pushkinskiye gory
# Processing Record 49 of Set 13 | bukama
# Processing Record 50 of Set 13 | joensuu
# Processing Record 1 of Set 14 | port augusta
# Processing Record 2 of Set 14 | lincoln
# Processing Record 3 of Set 14 | havoysund
# Processing Record 4 of Set 14 | chenzhou
# Processing Record 5 of Set 14 | whitley bay
# Processing Record 6 of Set 14 | anadyr
# Processing Record 7 of Set 14 | boyolangu
# Processing Record 8 of Set 14 | chistogorskiy
# Processing Record 9 of Set 14 | bolobo
# Processing Record 10 of Set 14 | campbell river
# Processing Record 11 of Set 14 | marfino
# Processing Record 12 of Set 14 | dilla
# Processing Record 13 of Set 14 | chongwe
# Processing Record 14 of Set 14 | xining
# Processing Record 15 of Set 14 | zyryanka
# Processing Record 16 of Set 14 | ketchikan
# Processing Record 17 of Set 14 | karasjok
# Processing Record 18 of Set 14 | linden
# Processing Record 19 of Set 14 | bubaque
# Processing Record 20 of Set 14 | zharkent
# Processing Record 21 of Set 14 | chernyy yar
# Processing Record 22 of Set 14 | aflu
# City not found. Skipping...
# Processing Record 23 of Set 14 | lisala
# Processing Record 24 of Set 14 | aipe
# Processing Record 25 of Set 14 | kungurtug
# Processing Record 26 of Set 14 | lubango
# Processing Record 27 of Set 14 | okahandja
# Processing Record 28 of Set 14 | porto murtinho
# Processing Record 29 of Set 14 | oudtshoorn
# Processing Record 30 of Set 14 | ongandjera
# Processing Record 31 of Set 14 | nenjiang
# Processing Record 32 of Set 14 | lobito
# Processing Record 33 of Set 14 | verkhnyaya inta
# Processing Record 34 of Set 14 | gazanjyk
# Processing Record 35 of Set 14 | bur gabo
# City not found. Skipping...
# Processing Record 36 of Set 14 | darhan
# Processing Record 37 of Set 14 | chumikan
# Processing Record 38 of Set 14 | maneadero
# Processing Record 39 of Set 14 | arlit
# Processing Record 40 of Set 14 | roros
# Processing Record 41 of Set 14 | ichchapuram
# Processing Record 42 of Set 14 | liverpool
# Processing Record 43 of Set 14 | dicabisagan
# Processing Record 44 of Set 14 | causapscal
# Processing Record 45 of Set 14 | karymskoye
# Processing Record 46 of Set 14 | husavik
# Processing Record 47 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 14 | uyuni
# Processing Record 49 of Set 14 | erdaojiang
# Processing Record 50 of Set 14 | sola
# Processing Record 1 of Set 15 | acari
# Processing Record 2 of Set 15 | hastings
# Processing Record 3 of Set 15 | pathein
# Processing Record 4 of Set 15 | karaman
# Processing Record 5 of Set 15 | sisimiut
# Processing Record 6 of Set 15 | aberdeen
# Processing Record 7 of Set 15 | lao cai
# Processing Record 8 of Set 15 | lakes entrance
# Processing Record 9 of Set 15 | san cristobal
# Processing Record 10 of Set 15 | marsh harbour
# Processing Record 11 of Set 15 | haines junction
# Processing Record 12 of Set 15 | bayan
# Processing Record 13 of Set 15 | nemuro
# Processing Record 14 of Set 15 | pangody
# Processing Record 15 of Set 15 | isiro
# Processing Record 16 of Set 15 | sao filipe
# Processing Record 17 of Set 15 | tatvan
# Processing Record 18 of Set 15 | sadat
# Processing Record 19 of Set 15 | lubao
# Processing Record 20 of Set 15 | horadiz
# Processing Record 21 of Set 15 | ishigaki
# Processing Record 22 of Set 15 | agua verde
# Processing Record 23 of Set 15 | barentu
# Processing Record 24 of Set 15 | barcelona
# Processing Record 25 of Set 15 | kamenskoye
# City not found. Skipping...
# Processing Record 26 of Set 15 | wahran
# City not found. Skipping...
# Processing Record 27 of Set 15 | ozernovskiy
# Processing Record 28 of Set 15 | palapye
# Processing Record 29 of Set 15 | ojinaga
# Processing Record 30 of Set 15 | salamanca
# Processing Record 31 of Set 15 | fonte boa
# Processing Record 32 of Set 15 | porto-vecchio
# Processing Record 33 of Set 15 | rurrenabaque
# Processing Record 34 of Set 15 | galle
# Processing Record 35 of Set 15 | collingwood
# Processing Record 36 of Set 15 | adelaide
# Processing Record 37 of Set 15 | jurado
# Processing Record 38 of Set 15 | louisbourg
# City not found. Skipping...
# Processing Record 39 of Set 15 | dunda
# Processing Record 40 of Set 15 | san vicente
# Processing Record 41 of Set 15 | thornbury
# Processing Record 42 of Set 15 | saint anthony
# Processing Record 43 of Set 15 | guayaramerin
# Processing Record 44 of Set 15 | nouakchott
# Processing Record 45 of Set 15 | banmo
# City not found. Skipping...
# Processing Record 46 of Set 15 | mata grande
# Processing Record 47 of Set 15 | manaus
# Processing Record 48 of Set 15 | mweka
# Processing Record 49 of Set 15 | waitati
# Processing Record 50 of Set 15 | yaan
# Processing Record 1 of Set 16 | hervey bay
# Processing Record 2 of Set 16 | rawson
# Processing Record 3 of Set 16 | presidencia roque saenz pena
# Processing Record 4 of Set 16 | shingu
# Processing Record 5 of Set 16 | ballina
# Processing Record 6 of Set 16 | kerrville
# Processing Record 7 of Set 16 | mogadishu
# Processing Record 8 of Set 16 | umzimvubu
# City not found. Skipping...
# Processing Record 9 of Set 16 | sao gabriel da cachoeira
# Processing Record 10 of Set 16 | colac
# Processing Record 11 of Set 16 | svetlogorsk
# Processing Record 12 of Set 16 | port hedland
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Reorganize the dataframe
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(5)
# Out:
#        City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  Nacajuca      MX  18.1333  -93.0167     82.45        78          49
# 1     Bluff      NZ -46.6000  168.3333     59.81        75         100
# 2    Castro      BR -24.7911  -50.0119     51.46        97         100
# 3  Tasiilaq      GL  65.6145  -37.6368     48.36        85          18
# 4   Aquiraz      BR  -3.9014  -38.3911     80.69        87           4
#
#    Wind Speed Current Description
# 0        4.61    scattered clouds
# 1       18.59     overcast clouds
# 2        7.76     overcast clouds
# 3        7.83          few clouds
# 4       14.36           clear sky

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
